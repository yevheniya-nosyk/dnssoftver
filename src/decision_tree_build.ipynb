# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics, tree
import pandas as pd
import collections
import json

# %%
# Read the input file and preprocess it
# - convert result dictionnaries to tuples for determinism

input_data = list()
with open("../signatures/signatures_all.json", "r") as f:
    for line in f:
        # Load the old entry
        entry = json.loads(line)
        # Store the processed entry
        entry_processed = collections.defaultdict(dict)
        for software in entry:
            # Test results are dictionnaries, which is not deterministic
            # Instead, we convert them into tuples
            for testcase in entry[software]:
                testresult = entry[software][testcase]
                if "error" in testresult:
                    testresult_new = tuple(sorted(list(testresult.items())))
                elif "answer" in testresult:
                    testresult_new = tuple(sorted(list(testresult["header"].items()) + list(testresult["answer"].items())))
                else:
                    testresult_new = tuple(sorted(list(testresult["header"].items())))
                entry_processed[software][testcase] = testresult_new

        input_data.append(dict(entry_processed))

# %%
# When we cannot uniquely identify a piece of software, one signature can correspond to multiple labels
# In this case, the classifier will not work properly
# So, we need to combine those labels with a pipe ("|")

signature_labels = collections.defaultdict(list)
for entry in input_data:
    for software in entry:
        signature = tuple((sorted(list(entry[software].items()))))
        signature_labels[signature].append(software)

input_data_processed = list()
for signature in signature_labels:
    labels_merged = "|".join(set(signature_labels[signature]))
    signature_dictionnary = {i[0]:i[1] for i in signature}
    for _ in range(len(signature_labels[signature])):
        input_data_processed.append({labels_merged:signature_dictionnary})

# %%
# Prepare the data to be loaded to a DataFrame

# Get all the column names from one of the entries
column_names_features = [j for i in input_data_processed[0].values() for j in i]
column_names_all = ["label"] + column_names_features

input_data_flat = list()
for entry in input_data_processed:
    for software in entry:
        entry_flat = list()
        for column in column_names_all:
            if column == "label":
                entry_flat.append(software)
            else:
                entry_flat.append(entry[software][column])
        input_data_flat.append(entry_flat)

# Load as a data frame
df = pd.DataFrame(input_data_flat, columns=column_names_all)
# Do the one hot encoding
df_one_hot = pd.get_dummies(data=df, columns=column_names_features)

# %%
# Split the dataset into features and target variables
X = df_one_hot.loc[:, df_one_hot.columns != 'label']
y = df_one_hot.label
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(random_state=1)
# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)
# Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Get some metrics
# In our example, the accuracy is always 0
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9980217606330366

# %%
# Our one-hot encoded feature names are too long, we need to try to shorten them
features_one_hot = df_one_hot.columns.difference(["label"], sort=False).tolist()

# Here we remove all the brackets and join by pipes
features_short = list()
# In this list we only keep testcase names
features_testcases = list()
for i in features_one_hot:
    features_short.append(i.replace("'","").replace("), (","|").replace(", ","-").replace("((","").replace("))","").replace("),)",""))
    features_testcases.append(i[:i.index("(")][:-1])

# %%
# Print the tree in a text form with feature names in a short format
text_representation = tree.export_text(clf,feature_names=features_short)
print(text_representation)
# Out:
# |--- test_home_arpa_AA-1|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |--- test_norec_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-0|TC-0 <= 0.50
# |   |   |--- test_norec_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-0|QR-1|RA-0|RCODE-REFUSED|RD-0|TC-0 <= 0.50
# |   |   |   |--- test_iquery_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-IQUERY|QDCOUNT-0|QR-1|RA-1|RCODE-NOTIMP|RD-1|TC-0 <= 0.50
# |   |   |   |   |--- test_tc_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-0|RCODE-FORMERR|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |--- test_31_172_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |--- test_baseline_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-2|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |   |--- test_iquery_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-IQUERY|QDCOUNT-1|QR-1|RA-1|RCODE-REFUSED|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |   |   |--- test_31_172_AA-1|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NXDOMAIN|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- test_tc_AA-0|AD-0|ANCOUNT-3|ARCOUNT-4|CD-0|NSCOUNT-2|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- test_chaos_rd_error-A DNS query response does not respond to the question asked. <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- test_chaos_rd_error-A DNS query response does not respond to the question asked. >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- test_tc_AA-0|AD-0|ANCOUNT-3|ARCOUNT-4|CD-0|NSCOUNT-2|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- test_home_arpa_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-SERVFAIL|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: bind9-9.10.5-p3:latest|bind9-9.10.5rc3:latest|bind9-9.11.1b1:latest|bind9-9.10.5:latest|bind9-9.11.1:latest|bind9-9.11.1-p3:latest|bind9-9.11.1rc1:latest|bind9-9.11.1-p1:latest|bind9-9.11.1rc3:latest|bind9-9.10.5-p1:latest|bind9-9.10.5-p2:latest|bind9-9.11.1-p2:latest|bind9-9.10.5rc1:latest|bind9-9.10.5b1:latest
# |   |   |   |   |   |   |   |   |   |   |--- test_home_arpa_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-SERVFAIL|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: bind9-9.10.5rc3:latest|bind9-9.11.1rc3:latest|bind9-9.10.5-p1:latest|bind9-9.10.5-p2:latest|bind9-9.10.5b1:latest
# |   |   |   |   |   |   |   |   |--- test_31_172_AA-1|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NXDOMAIN|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: cznic/knot-resolver:v5.3.2|cznic/knot-resolver:v5.3.0|cznic/knot-resolver:v5.1.0|cznic/knot-resolver:v5.1.1|cznic/knot-resolver:v5.2.1|cznic/knot-resolver:v5.3.1|cznic/knot-resolver:v5.4.0|cznic/knot-resolver:v5.4.2|cznic/knot-resolver:v5.2.0|cznic/knot-resolver:v5.1.3|cznic/knot-resolver:v5.1.2|cznic/knot-resolver:v5.4.1
# |   |   |   |   |   |   |   |--- test_iquery_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-IQUERY|QDCOUNT-1|QR-1|RA-1|RCODE-REFUSED|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |   |   |--- test_zero_ttl_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0|TTL-1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: technitium-2.0.1:latest|technitium-1.2.0.1:latest|technitium-1.3.0.0:latest|technitium-1.2.2.0:latest|technitium-1.2.3.0:latest|technitium-2.0.2:latest|technitium-1.3.2:latest|technitium-1.1:latest|technitium-1.3.3:latest|technitium-1.3.0.1:latest|technitium-2.0.0.1:latest|technitium-1.2:latest|technitium-1.0:latest
# |   |   |   |   |   |   |   |   |--- test_zero_ttl_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0|TTL-1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- test_31_172_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-SERVFAIL|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: technitium-2.4:latest|technitium-4.0:latest|technitium-3.0:latest|technitium-2.2:latest|technitium-3.3:latest|technitium-3.1:latest|technitium-3.2:latest|technitium-2.3.0.1:latest|technitium-2.3.1:latest|technitium-2.1:latest|technitium-2.3:latest|technitium-4.1:latest|technitium-2.3.0.2:latest
# |   |   |   |   |   |   |   |   |   |--- test_31_172_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-SERVFAIL|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: technitium-4.0:latest
# |   |   |   |   |   |   |--- test_baseline_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-2|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |   |--- test_home_arpa_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: bind9-9.10.6rc1:latest|bind9-9.10.7b1:latest|bind9-9.11.3:latest|bind9-9.10.7rc2:latest|bind9-9.11.3b1:latest|bind9-9.11.2:latest|bind9-9.10.6:latest
# |   |   |   |   |   |   |   |--- test_home_arpa_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |   |   |--- class: bind9-9.11.2rc1:latest|bind9-9.11.2rc2:latest|bind9-9.10.6rc1:latest|bind9-9.11.3rc1:latest|bind9-9.10.6-p1:latest|bind9-9.10.7b1:latest|bind9-9.11.3:latest|bind9-9.10.7rc2:latest|bind9-9.11.3b1:latest|bind9-9.10.7rc1:latest|bind9-9.10.6rc2:latest|bind9-9.10.6b1:latest|bind9-9.10.7:latest|bind9-9.11.2b1:latest|bind9-9.11.3rc2:latest|bind9-9.11.2:latest|bind9-9.11.2-p1:latest|bind9-9.10.6:latest
# |   |   |   |   |   |--- test_31_172_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |--- test_chaos_rd_error-Timeout <= 0.50
# |   |   |   |   |   |   |   |--- class: technitium-11.0.2:latest|technitium-11.0.1:latest|technitium-10.0.1:latest|technitium-9.0:latest|technitium-11.2:latest|technitium-11.4.1:latest|technitium-11.1.1:latest|technitium-8.0.1:latest|technitium-8.1.2:latest|technitium-11.0.3:latest|technitium-9.1:latest|technitium-10.0:latest|technitium-8.0.2:latest|technitium-8.1:latest|technitium-11.4:latest|technitium-8.1.1:latest|technitium-8.1.3:latest|technitium-11.3:latest|technitium-8.0:latest|technitium-11.1:latest|technitium-11.0:latest|technitium-8.1.4:latest
# |   |   |   |   |   |   |--- test_chaos_rd_error-Timeout >  0.50
# |   |   |   |   |   |   |   |--- class: windows-server:2022|windows-server:2019|windows-server:2016
# |   |   |   |   |--- test_tc_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-0|RCODE-FORMERR|RD-1|TC-0 >  0.50
# |   |   |   |   |   |--- test_zero_ttl_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0|TTL-0 <= 0.50
# |   |   |   |   |   |   |--- class: unbound-1.7.2rc1:latest|unbound-1.7.3rc2:latest|unbound-1.7.0:latest|unbound-1.7.0rc1:latest|unbound-1.7.0rc3:latest|unbound-1.7.3:latest|unbound-1.7.3rc1:latest|unbound-1.7.2:latest|unbound-1.7.0rc2:latest|unbound-1.7.1:latest
# |   |   |   |   |   |--- test_zero_ttl_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0|TTL-0 >  0.50
# |   |   |   |   |   |   |--- class: unbound-1.13.1:latest|unbound-1.13.1rc2:latest|unbound-1.9.4:latest|unbound-1.11.0:latest|unbound-1.9.2rc2:latest|unbound-1.9.2rc1:latest|unbound-1.9.3:latest|unbound-1.12.0rc1:latest|unbound-1.9.2:latest|unbound-1.9.3rc1:latest|unbound-1.12.0:latest|unbound-1.10.0:latest|unbound-1.8.0:latest|unbound-1.8.2rc1:latest|unbound-1.9.6:latest|unbound-1.13.0rc1:latest|unbound-1.10.0rc1:latest|unbound-1.9.3rc2:latest|unbound-1.8.2:latest|unbound-1.10.1:latest|unbound-1.9.0:latest|unbound-1.9.1:latest|unbound-1.9.0rc1:latest|unbound-1.8.1rc1:latest|unbound-1.11.0rc1:latest|unbound-1.9.5:latest|unbound-1.8.3:latest|unbound-1.13.0rc3:latest|unbound-1.8.1:latest|unbound-1.13.2rc1:latest|unbound-1.9.1rc1:latest|unbound-1.13.1rc1:latest|unbound-1.8.0rc1:latest|unbound-1.9.2rc3:latest|unbound-1.13.0rc4:latest|unbound-1.13.0rc2:latest|unbound-1.9.6rc1:latest|unbound-1.13.2:latest|unbound-1.13.0:latest|unbound-1.10.0rc2:latest
# |   |   |   |--- test_iquery_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-IQUERY|QDCOUNT-0|QR-1|RA-1|RCODE-NOTIMP|RD-1|TC-0 >  0.50
# |   |   |   |   |--- test_edns0_AA-0|AD-0|ANCOUNT-3|ARCOUNT-5|CD-0|NSCOUNT-2|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |--- test_home_arpa_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |--- class: bind9-9.10.3-p3:latest|bind9-9.10.3-p4:latest|bind9-9.10.2-p1:latest|bind9-9.10.1:latest|bind9-9.11.0-p1:latest|bind9-9.10.4-p3:latest|bind9-9.10.1b1:latest|bind9-9.10.4-p5:latest|bind9-9.10.1-p1:latest|bind9-9.10.4-p8:latest
# |   |   |   |   |   |--- test_home_arpa_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |--- class: bind9-9.10.3-p3:latest|bind9-9.10.2rc1:latest|bind9-9.10.3b1:latest|bind9-9.10.4b3:latest|bind9-9.10.4-p1:latest|bind9-9.10.1:latest|bind9-9.10.4-p5:latest|bind9-9.10.4-p2:latest|bind9-9.10.4-p4:latest|bind9-9.10.1rc1:latest|bind9-9.11.0-p5:latest|bind9-9.10.2rc2:latest|bind9-9.11.0rc1:latest|bind9-9.10.4b2:latest|bind9-9.11.0rc3:latest|bind9-9.10.3-p2:latest|bind9-9.10.2-p3:latest|bind9-9.10.3:latest|bind9-9.10.4-p8:latest|bind9-9.10.1rc2:latest|bind9-9.11.0b3:latest|bind9-9.11.0-p1:latest|bind9-9.10.0a1:latest|bind9-9.10.4-p6:latest|bind9-9.11.0a3:latest|bind9-9.10.0a2:latest|bind9-9.11.0a1:latest|bind9-9.10.1-p2:latest|bind9-9.10.2-p1:latest|bind9-9.10.2b1:latest|bind9-9.11.0a2:latest|bind9-9.10.4-p3:latest|bind9-9.10.1b2:latest|bind9-9.10.4rc1:latest|bind9-9.11.0-p3:latest|bind9-9.10.1-p1:latest|bind9-9.11.0b2:latest|bind9-9.10.2-p2:latest|bind9-9.11.0:latest|bind9-9.11.0-p2:latest|bind9-9.10.2-p4:latest|bind9-9.10.3-p4:latest|bind9-9.10.1b1:latest|bind9-9.11.0b1:latest|bind9-9.10.3rc1:latest|bind9-9.10.4:latest|bind9-9.10.4b1:latest|bind9-9.10.2:latest
# |   |   |   |   |--- test_edns0_AA-0|AD-0|ANCOUNT-3|ARCOUNT-5|CD-0|NSCOUNT-2|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |   |   |   |--- test_home_arpa_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |   |   |   |   |--- class: bind9-9.10.0:latest|bind9-9.10.0b1:latest
# |   |   |   |   |   |--- test_home_arpa_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |   |   |   |   |--- class: bind9-9.10.0b2:latest|bind9-9.10.0-p1:latest|bind9-9.10.0rc2:latest|bind9-9.10.0b1:latest|bind9-9.10.0-p2:latest|bind9-9.10.0:latest|bind9-9.10.0rc1:latest
# |   |   |--- test_norec_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-0|QR-1|RA-0|RCODE-REFUSED|RD-0|TC-0 >  0.50
# |   |   |   |--- class: unbound-1.5.6rc1:latest|unbound-1.5.8rc1:latest|unbound-1.5.0rc1:latest|unbound-1.6.1rc2:latest|unbound-1.5.0:latest|unbound-1.5.9rc1:latest|unbound-1.5.2rc1:latest|unbound-1.6.6rc1:latest|unbound-1.5.7:latest|unbound-1.5.3:latest|unbound-1.6.4:latest|unbound-1.6.8:latest|unbound-1.5.10:latest|unbound-1.6.6rc2:latest|unbound-1.6.1:latest|unbound-1.6.2rc1:latest|unbound-1.6.4rc2:latest|unbound-1.6.1rc1:latest|unbound-1.5.1rc2:latest|unbound-1.6.7rc1:latest|unbound-1.5.4rc1:latest|unbound-1.6.6:latest|unbound-1.6.4rc1:latest|unbound-1.6.2:latest|unbound-1.6.5:latest|unbound-1.5.1rc1:latest|unbound-1.5.6:latest|unbound-1.5.3rc1:latest|unbound-1.6.3:latest|unbound-1.5.10rc1:latest|unbound-1.5.8:latest|unbound-1.6.0:latest|unbound-1.5.7rc1:latest|unbound-1.5.4:latest|unbound-1.6.0rc1:latest|unbound-1.5.5:latest|unbound-1.6.7:latest|unbound-1.5.9:latest|unbound-1.5.1:latest|unbound-1.5.5rc1:latest|unbound-1.6.1rc3:latest|unbound-1.5.2:latest
# |   |--- test_norec_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-0|TC-0 >  0.50
# |   |   |--- test_zero_ttl_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0|TTL-1 <= 0.50
# |   |   |   |--- test_31_172_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |   |   |--- class: pdns-recursor-4.0.0:latest|pdns-recursor-4.0.2:latest|pdns-recursor-4.0.4:latest|pdns-recursor-4.0.3:latest|pdns-recursor-4.0.0-rc1:latest|pdns-recursor-4.0.1:latest
# |   |   |   |--- test_31_172_AA-0|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |   |   |--- class: pdns-recursor-4.1.14:latest|pdns-recursor-4.3.7:latest|pdns-recursor-4.4.0-rc2:latest|pdns-recursor-4.1.18:latest|pdns-recursor-4.1.4:latest|pdns-recursor-4.4.0-alpha1:latest|pdns-recursor-4.0.6:latest|pdns-recursor-4.4.3:latest|pdns-recursor-4.1.0-alpha1:latest|pdns-recursor-4.0.0-beta1:latest|pdns-recursor-4.1.11:latest|pdns-recursor-4.1.5:latest|pdns-recursor-4.1.6:latest|pdns-recursor-4.0.5-rc2:latest|pdns-recursor-4.1.7:latest|pdns-recursor-4.2.0-alpha1:latest|pdns-recursor-4.2.1:latest|pdns-recursor-4.2.2:latest|pdns-recursor-4.2.0-rc1:latest|pdns-recursor-4.3.0-beta2:latest|pdns-recursor-4.3.6:latest|pdns-recursor-4.3.0-alpha3:latest|pdns-recursor-4.1.0-rc1:latest|pdns-recursor-4.3.0:latest|pdns-recursor-4.0.5-rc1:latest|pdns-recursor-4.1.3:latest|pdns-recursor-4.4.0:latest|pdns-recursor-4.1.13:latest|pdns-recursor-4.3.1:latest|pdns-recursor-4.2.5:latest|pdns-recursor-4.4.6:latest|pdns-recursor-4.4.7:latest|pdns-recursor-4.2.0-beta1:latest|pdns-recursor-4.0.0-alpha2:latest|pdns-recursor-4.1.12:latest|pdns-recursor-4.2.4:latest|pdns-recursor-4.1.16:latest|pdns-recursor-4.2.0-rc2:latest|pdns-recursor-4.0.5:latest|pdns-recursor-4.3.4:latest|pdns-recursor-4.4.1:latest|pdns-recursor-4.3.0-rc1:latest|pdns-recursor-4.0.9:latest|pdns-recursor-4.1.0-rc2:latest|pdns-recursor-4.0.8:latest|pdns-recursor-4.1.8:latest|pdns-recursor-4.1.17:latest|pdns-recursor-4.1.10:latest|pdns-recursor-4.4.2:latest|pdns-recursor-4.4.0-alpha2:latest|pdns-recursor-4.4.0-beta1:latest|pdns-recursor-4.0.0-alpha1:latest|pdns-recursor-4.2.3:latest|pdns-recursor-4.1.0:latest|pdns-recursor-4.3.0-beta1:latest|pdns-recursor-4.1.15:latest|pdns-recursor-4.4.8:latest|pdns-recursor-4.3.0-rc2:latest|pdns-recursor-4.4.0-rc1:latest|pdns-recursor-4.3.2:latest|pdns-recursor-4.1.1:latest|pdns-recursor-4.1.2:latest|pdns-recursor-4.3.3:latest|pdns-recursor-4.4.4:latest|pdns-recursor-4.3.5:latest|pdns-recursor-4.0.7:latest|pdns-recursor-4.4.5:latest|pdns-recursor-4.3.0-alpha1:latest|pdns-recursor-4.2.0:latest
# |   |   |--- test_zero_ttl_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0|TTL-1 >  0.50
# |   |   |   |--- class: pdns-recursor-4.8.0-beta1:latest|pdns-recursor-4.7.0-beta1:latest|pdns-recursor-4.6.3:latest|pdns-recursor-4.7.0-alpha1:latest|pdns-recursor-4.9.1:latest|pdns-recursor-4.5.0-beta2:latest|pdns-recursor-4.5.0-alpha1:latest|pdns-recursor-4.5.5:latest|pdns-recursor-4.8.2:latest|pdns-recursor-4.7.6:latest|pdns-recursor-4.7.0-rc1:latest|pdns-recursor-4.8.0:latest|pdns-recursor-4.8.0-alpha1:latest|pdns-recursor-4.6.5:latest|pdns-recursor-4.5.10:latest|pdns-recursor-4.7.1:latest|pdns-recursor-4.7.0:latest|pdns-recursor-4.9.0-beta1:latest|pdns-recursor-4.8.4:latest|pdns-recursor-4.5.8:latest|pdns-recursor-4.5.0-beta1:latest|pdns-recursor-4.8.1:latest|pdns-recursor-4.5.0-rc1:latest|pdns-recursor-4.8.3:latest|pdns-recursor-4.9.0-alpha1:latest|pdns-recursor-4.6.6:latest|pdns-recursor-4.5.2:latest|pdns-recursor-4.6.2:latest|pdns-recursor-4.7.2:latest|pdns-recursor-4.6.4:latest|pdns-recursor-4.7.4:latest|pdns-recursor-4.5.0-alpha3:latest|pdns-recursor-4.5.9:latest|pdns-recursor-4.7.5:latest|pdns-recursor-4.9.0:latest|pdns-recursor-4.7.3:latest|pdns-recursor-4.8.5:latest|pdns-recursor-4.9.0-rc1:latest|pdns-recursor-4.8.0-rc1:latest|pdns-recursor-4.5.7:latest|pdns-recursor-4.5.1:latest|pdns-recursor-4.5.6:latest|pdns-recursor-4.5.11:latest|pdns-recursor-4.5.4:latest|pdns-recursor-4.5.12:latest|pdns-recursor-4.8.0-beta2:latest
# |--- test_home_arpa_AA-1|AD-0|ANCOUNT-0|ARCOUNT-1|CD-0|NSCOUNT-1|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |--- test_tc_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 <= 0.50
# |   |   |--- test_chaos_rd_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-REFUSED|RD-1|TC-0 <= 0.50
# |   |   |   |--- class: bind9-9.11.33:latest|bind9-9.10.8rc1:latest|bind9-9.11.5-p4:latest|bind9-9.11.28:latest|bind9-9.11.9:latest|bind9-9.11.16:latest|bind9-9.11.35:latest|bind9-9.11.6rc1:latest|bind9-9.11.12:latest|bind9-9.11.4-p1:latest|bind9-9.11.27:latest|bind9-9.10.8rc2:latest|bind9-9.11.19:latest|bind9-9.11.4-p2:latest|bind9-9.11.4rc1:latest|bind9-9.11.4rc2:latest|bind9-9.11.5:latest|bind9-9.11.29:latest|bind9-9.11.5rc1:latest|bind9-9.11.13:latest|bind9-9.11.36:latest|bind9-9.11.17:latest|bind9-9.11.25:latest|bind9-9.11.21:latest|bind9-9.11.32:latest|bind9-9.11.26:latest|bind9-9.11.18:latest|bind9-9.11.24:latest|bind9-9.11.7:latest|bind9-9.11.5-p1:latest|bind9-9.11.14:latest|bind9-9.11.34:latest|bind9-9.10.8:latest|bind9-9.11.8:latest|bind9-9.11.23:latest|bind9-9.11.10:latest|bind9-9.11.15:latest|bind9-9.10.8-p1:latest|bind9-9.11.20:latest|bind9-9.11.6-p1:latest|bind9-9.11.37:latest|bind9-9.11.11:latest|bind9-9.11.31:latest|bind9-9.11.4:latest|bind9-9.11.6:latest|bind9-9.11.22:latest
# |   |   |--- test_chaos_rd_AA-0|AD-0|ANCOUNT-0|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-REFUSED|RD-1|TC-0 >  0.50
# |   |   |   |--- class: unbound-1.16.0:latest|unbound-1.17.1rc1:latest|unbound-1.17.0:latest|unbound-1.15.0:latest|unbound-1.14.0:latest|unbound-1.16.3:latest|unbound-1.17.1rc2:latest|unbound-1.16.0rc1:latest|unbound-1.16.1rc1:latest|unbound-1.15.0rc1:latest|unbound-1.16.2:latest|unbound-1.17.0rc1:latest|unbound-1.17.1:latest|unbound-1.16.1:latest|unbound-1.14.0rc1:latest
# |   |--- test_tc_AA-0|AD-0|ANCOUNT-3|ARCOUNT-0|CD-0|NSCOUNT-0|Opcode-QUERY|QDCOUNT-1|QR-1|RA-1|RCODE-NOERROR|RD-1|TC-0 >  0.50
# |   |   |--- class: bind9-9.19.6:latest|bind9-9.16.19:latest|bind9-9.16.34:latest|bind9-9.19.12:latest|bind9-9.13.7:latest|bind9-9.18.4:latest|bind9-9.16.32:latest|bind9-9.14.7:latest|bind9-9.17.1:latest|bind9-9.16.29:latest|bind9-9.17.4:latest|bind9-9.18.16:latest|bind9-9.16.40:latest|bind9-9.18.13:latest|bind9-9.15.0:latest|bind9-9.19.9:latest|bind9-9.18.8:latest|bind9-9.17.16:latest|bind9-9.14.4:latest|bind9-9.18.2:latest|bind9-9.16.36:latest|bind9-9.15.5:latest|bind9-9.16.25:latest|bind9-9.15.4:latest|bind9-9.16.0:latest|bind9-9.16.39:latest|bind9-9.12.2-p2:latest|bind9-9.16.26:latest|bind9-9.16.22:latest|bind9-9.19.5:latest|bind9-9.18.15:latest|bind9-9.16.20:latest|bind9-9.18.1:latest|bind9-9.13.5-w1:latest|bind9-9.16.7:latest|bind9-9.19.3:latest|bind9-9.17.11:latest|bind9-9.14.0rc3:latest|bind9-9.16.6:latest|bind9-9.16.24:latest|bind9-9.16.9:latest|bind9-9.17.5:latest|bind9-9.12.3-p4:latest|bind9-9.12.2:latest|bind9-9.16.28:latest|bind9-9.17.8:latest|bind9-9.18.12:latest|bind9-9.17.18:latest|bind9-9.17.14:latest|bind9-9.14.6:latest|bind9-9.18.17:latest|bind9-9.19.1:latest|bind9-9.14.10:latest|bind9-9.17.3:latest|bind9-9.14.9:latest|bind9-9.17.13:latest|bind9-9.18.9:latest|bind9-9.12.4:latest|bind9-9.16.1:latest|bind9-9.12.2-p1:latest|bind9-9.16.30:latest|bind9-9.16.10:latest|bind9-9.15.6:latest|bind9-9.17.2:latest|bind9-9.19.14:latest|bind9-9.16.38:latest|bind9-9.18.14:latest|bind9-9.12.3-p1:latest|bind9-9.16.42:latest|bind9-9.16.23:latest|bind9-9.19.13:latest|bind9-9.16.41:latest|bind9-9.18.0:latest|bind9-9.16.8:latest|bind9-9.17.22:latest|bind9-9.14.11:latest|bind9-9.19.4:latest|bind9-9.16.13:latest|bind9-9.16.18:latest|bind9-9.13.3:latest|bind9-9.14.5:latest|bind9-9.13.4:latest|bind9-9.18.10:latest|bind9-9.14.0:latest|bind9-9.14.3:latest|bind9-9.12.2rc2:latest|bind9-9.16.5:latest|bind9-9.14.8:latest|bind9-9.16.16:latest|bind9-9.19.0:latest|bind9-9.13.2:latest|bind9-9.12.4-p2:latest|bind9-9.14.2:latest|bind9-9.18.18:latest|bind9-9.14.12:latest|bind9-9.17.15:latest|bind9-9.16.12:latest|bind9-9.16.37:latest|bind9-9.19.11:latest|bind9-9.13.1:latest|bind9-9.17.9:latest|bind9-9.15.2:latest|bind9-9.16.17:latest|bind9-9.16.31:latest|bind9-9.17.17:latest|bind9-9.17.7:latest|bind9-9.17.19:latest|bind9-9.16.35:latest|bind9-9.18.5:latest|bind9-9.16.15:latest|bind9-9.16.27:latest|bind9-9.15.7:latest|bind9-9.15.3:latest|bind9-9.16.4:latest|bind9-9.16.33:latest|bind9-9.16.3:latest|bind9-9.12.3rc1:latest|bind9-9.18.6:latest|bind9-9.17.10:latest|bind9-9.12.3:latest|bind9-9.19.16:latest|bind9-9.18.3:latest|bind9-9.18.11:latest|bind9-9.14.0rc2:latest|bind9-9.17.6:latest|bind9-9.16.21:latest|bind9-9.17.12:latest|bind9-9.14.0rc1:latest|bind9-9.14.1:latest|bind9-9.19.10:latest|bind9-9.15.1:latest|bind9-9.17.0:latest|bind9-9.13.5:latest|bind9-9.16.11:latest|bind9-9.19.8:latest|bind9-9.12.2rc1:latest|bind9-9.17.21:latest|bind9-9.12.4-p1:latest|bind9-9.19.7:latest|bind9-9.19.15:latest|bind9-9.15.8:latest|bind9-9.12.4rc1:latest|bind9-9.13.6:latest|bind9-9.17.20:latest|bind9-9.16.43:latest|bind9-9.18.7:latest|bind9-9.16.2:latest|bind9-9.19.2:latest

# %%
# Print the tree in a text form with feature names as testcases
text_representation = tree.export_text(clf,feature_names=features_testcases)
print(text_representation)
# Out:
# |--- test_home_arpa <= 0.50
# |   |--- test_norec <= 0.50
# |   |   |--- test_norec <= 0.50
# |   |   |   |--- test_iquery <= 0.50
# |   |   |   |   |--- test_tc <= 0.50
# |   |   |   |   |   |--- test_31_172 <= 0.50
# |   |   |   |   |   |   |--- test_baseline <= 0.50
# |   |   |   |   |   |   |   |--- test_iquery <= 0.50
# |   |   |   |   |   |   |   |   |--- test_31_172 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- test_tc <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- test_chaos_rd <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- test_chaos_rd >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- test_tc >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- test_home_arpa <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: bind9-9.10.5-p3:latest|bind9-9.10.5rc3:latest|bind9-9.11.1b1:latest|bind9-9.10.5:latest|bind9-9.11.1:latest|bind9-9.11.1-p3:latest|bind9-9.11.1rc1:latest|bind9-9.11.1-p1:latest|bind9-9.11.1rc3:latest|bind9-9.10.5-p1:latest|bind9-9.10.5-p2:latest|bind9-9.11.1-p2:latest|bind9-9.10.5rc1:latest|bind9-9.10.5b1:latest
# |   |   |   |   |   |   |   |   |   |   |--- test_home_arpa >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: bind9-9.10.5rc3:latest|bind9-9.11.1rc3:latest|bind9-9.10.5-p1:latest|bind9-9.10.5-p2:latest|bind9-9.10.5b1:latest
# |   |   |   |   |   |   |   |   |--- test_31_172 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: cznic/knot-resolver:v5.3.2|cznic/knot-resolver:v5.3.0|cznic/knot-resolver:v5.1.0|cznic/knot-resolver:v5.1.1|cznic/knot-resolver:v5.2.1|cznic/knot-resolver:v5.3.1|cznic/knot-resolver:v5.4.0|cznic/knot-resolver:v5.4.2|cznic/knot-resolver:v5.2.0|cznic/knot-resolver:v5.1.3|cznic/knot-resolver:v5.1.2|cznic/knot-resolver:v5.4.1
# |   |   |   |   |   |   |   |--- test_iquery >  0.50
# |   |   |   |   |   |   |   |   |--- test_zero_ttl <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: technitium-2.0.1:latest|technitium-1.2.0.1:latest|technitium-1.3.0.0:latest|technitium-1.2.2.0:latest|technitium-1.2.3.0:latest|technitium-2.0.2:latest|technitium-1.3.2:latest|technitium-1.1:latest|technitium-1.3.3:latest|technitium-1.3.0.1:latest|technitium-2.0.0.1:latest|technitium-1.2:latest|technitium-1.0:latest
# |   |   |   |   |   |   |   |   |--- test_zero_ttl >  0.50
# |   |   |   |   |   |   |   |   |   |--- test_31_172 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: technitium-2.4:latest|technitium-4.0:latest|technitium-3.0:latest|technitium-2.2:latest|technitium-3.3:latest|technitium-3.1:latest|technitium-3.2:latest|technitium-2.3.0.1:latest|technitium-2.3.1:latest|technitium-2.1:latest|technitium-2.3:latest|technitium-4.1:latest|technitium-2.3.0.2:latest
# |   |   |   |   |   |   |   |   |   |--- test_31_172 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: technitium-4.0:latest
# |   |   |   |   |   |   |--- test_baseline >  0.50
# |   |   |   |   |   |   |   |--- test_home_arpa <= 0.50
# |   |   |   |   |   |   |   |   |--- class: bind9-9.10.6rc1:latest|bind9-9.10.7b1:latest|bind9-9.11.3:latest|bind9-9.10.7rc2:latest|bind9-9.11.3b1:latest|bind9-9.11.2:latest|bind9-9.10.6:latest
# |   |   |   |   |   |   |   |--- test_home_arpa >  0.50
# |   |   |   |   |   |   |   |   |--- class: bind9-9.11.2rc1:latest|bind9-9.11.2rc2:latest|bind9-9.10.6rc1:latest|bind9-9.11.3rc1:latest|bind9-9.10.6-p1:latest|bind9-9.10.7b1:latest|bind9-9.11.3:latest|bind9-9.10.7rc2:latest|bind9-9.11.3b1:latest|bind9-9.10.7rc1:latest|bind9-9.10.6rc2:latest|bind9-9.10.6b1:latest|bind9-9.10.7:latest|bind9-9.11.2b1:latest|bind9-9.11.3rc2:latest|bind9-9.11.2:latest|bind9-9.11.2-p1:latest|bind9-9.10.6:latest
# |   |   |   |   |   |--- test_31_172 >  0.50
# |   |   |   |   |   |   |--- test_chaos_rd <= 0.50
# |   |   |   |   |   |   |   |--- class: technitium-11.0.2:latest|technitium-11.0.1:latest|technitium-10.0.1:latest|technitium-9.0:latest|technitium-11.2:latest|technitium-11.4.1:latest|technitium-11.1.1:latest|technitium-8.0.1:latest|technitium-8.1.2:latest|technitium-11.0.3:latest|technitium-9.1:latest|technitium-10.0:latest|technitium-8.0.2:latest|technitium-8.1:latest|technitium-11.4:latest|technitium-8.1.1:latest|technitium-8.1.3:latest|technitium-11.3:latest|technitium-8.0:latest|technitium-11.1:latest|technitium-11.0:latest|technitium-8.1.4:latest
# |   |   |   |   |   |   |--- test_chaos_rd >  0.50
# |   |   |   |   |   |   |   |--- class: windows-server:2022|windows-server:2019|windows-server:2016
# |   |   |   |   |--- test_tc >  0.50
# |   |   |   |   |   |--- test_zero_ttl <= 0.50
# |   |   |   |   |   |   |--- class: unbound-1.7.2rc1:latest|unbound-1.7.3rc2:latest|unbound-1.7.0:latest|unbound-1.7.0rc1:latest|unbound-1.7.0rc3:latest|unbound-1.7.3:latest|unbound-1.7.3rc1:latest|unbound-1.7.2:latest|unbound-1.7.0rc2:latest|unbound-1.7.1:latest
# |   |   |   |   |   |--- test_zero_ttl >  0.50
# |   |   |   |   |   |   |--- class: unbound-1.13.1:latest|unbound-1.13.1rc2:latest|unbound-1.9.4:latest|unbound-1.11.0:latest|unbound-1.9.2rc2:latest|unbound-1.9.2rc1:latest|unbound-1.9.3:latest|unbound-1.12.0rc1:latest|unbound-1.9.2:latest|unbound-1.9.3rc1:latest|unbound-1.12.0:latest|unbound-1.10.0:latest|unbound-1.8.0:latest|unbound-1.8.2rc1:latest|unbound-1.9.6:latest|unbound-1.13.0rc1:latest|unbound-1.10.0rc1:latest|unbound-1.9.3rc2:latest|unbound-1.8.2:latest|unbound-1.10.1:latest|unbound-1.9.0:latest|unbound-1.9.1:latest|unbound-1.9.0rc1:latest|unbound-1.8.1rc1:latest|unbound-1.11.0rc1:latest|unbound-1.9.5:latest|unbound-1.8.3:latest|unbound-1.13.0rc3:latest|unbound-1.8.1:latest|unbound-1.13.2rc1:latest|unbound-1.9.1rc1:latest|unbound-1.13.1rc1:latest|unbound-1.8.0rc1:latest|unbound-1.9.2rc3:latest|unbound-1.13.0rc4:latest|unbound-1.13.0rc2:latest|unbound-1.9.6rc1:latest|unbound-1.13.2:latest|unbound-1.13.0:latest|unbound-1.10.0rc2:latest
# |   |   |   |--- test_iquery >  0.50
# |   |   |   |   |--- test_edns0 <= 0.50
# |   |   |   |   |   |--- test_home_arpa <= 0.50
# |   |   |   |   |   |   |--- class: bind9-9.10.3-p3:latest|bind9-9.10.3-p4:latest|bind9-9.10.2-p1:latest|bind9-9.10.1:latest|bind9-9.11.0-p1:latest|bind9-9.10.4-p3:latest|bind9-9.10.1b1:latest|bind9-9.10.4-p5:latest|bind9-9.10.1-p1:latest|bind9-9.10.4-p8:latest
# |   |   |   |   |   |--- test_home_arpa >  0.50
# |   |   |   |   |   |   |--- class: bind9-9.10.3-p3:latest|bind9-9.10.2rc1:latest|bind9-9.10.3b1:latest|bind9-9.10.4b3:latest|bind9-9.10.4-p1:latest|bind9-9.10.1:latest|bind9-9.10.4-p5:latest|bind9-9.10.4-p2:latest|bind9-9.10.4-p4:latest|bind9-9.10.1rc1:latest|bind9-9.11.0-p5:latest|bind9-9.10.2rc2:latest|bind9-9.11.0rc1:latest|bind9-9.10.4b2:latest|bind9-9.11.0rc3:latest|bind9-9.10.3-p2:latest|bind9-9.10.2-p3:latest|bind9-9.10.3:latest|bind9-9.10.4-p8:latest|bind9-9.10.1rc2:latest|bind9-9.11.0b3:latest|bind9-9.11.0-p1:latest|bind9-9.10.0a1:latest|bind9-9.10.4-p6:latest|bind9-9.11.0a3:latest|bind9-9.10.0a2:latest|bind9-9.11.0a1:latest|bind9-9.10.1-p2:latest|bind9-9.10.2-p1:latest|bind9-9.10.2b1:latest|bind9-9.11.0a2:latest|bind9-9.10.4-p3:latest|bind9-9.10.1b2:latest|bind9-9.10.4rc1:latest|bind9-9.11.0-p3:latest|bind9-9.10.1-p1:latest|bind9-9.11.0b2:latest|bind9-9.10.2-p2:latest|bind9-9.11.0:latest|bind9-9.11.0-p2:latest|bind9-9.10.2-p4:latest|bind9-9.10.3-p4:latest|bind9-9.10.1b1:latest|bind9-9.11.0b1:latest|bind9-9.10.3rc1:latest|bind9-9.10.4:latest|bind9-9.10.4b1:latest|bind9-9.10.2:latest
# |   |   |   |   |--- test_edns0 >  0.50
# |   |   |   |   |   |--- test_home_arpa <= 0.50
# |   |   |   |   |   |   |--- class: bind9-9.10.0:latest|bind9-9.10.0b1:latest
# |   |   |   |   |   |--- test_home_arpa >  0.50
# |   |   |   |   |   |   |--- class: bind9-9.10.0b2:latest|bind9-9.10.0-p1:latest|bind9-9.10.0rc2:latest|bind9-9.10.0b1:latest|bind9-9.10.0-p2:latest|bind9-9.10.0:latest|bind9-9.10.0rc1:latest
# |   |   |--- test_norec >  0.50
# |   |   |   |--- class: unbound-1.5.6rc1:latest|unbound-1.5.8rc1:latest|unbound-1.5.0rc1:latest|unbound-1.6.1rc2:latest|unbound-1.5.0:latest|unbound-1.5.9rc1:latest|unbound-1.5.2rc1:latest|unbound-1.6.6rc1:latest|unbound-1.5.7:latest|unbound-1.5.3:latest|unbound-1.6.4:latest|unbound-1.6.8:latest|unbound-1.5.10:latest|unbound-1.6.6rc2:latest|unbound-1.6.1:latest|unbound-1.6.2rc1:latest|unbound-1.6.4rc2:latest|unbound-1.6.1rc1:latest|unbound-1.5.1rc2:latest|unbound-1.6.7rc1:latest|unbound-1.5.4rc1:latest|unbound-1.6.6:latest|unbound-1.6.4rc1:latest|unbound-1.6.2:latest|unbound-1.6.5:latest|unbound-1.5.1rc1:latest|unbound-1.5.6:latest|unbound-1.5.3rc1:latest|unbound-1.6.3:latest|unbound-1.5.10rc1:latest|unbound-1.5.8:latest|unbound-1.6.0:latest|unbound-1.5.7rc1:latest|unbound-1.5.4:latest|unbound-1.6.0rc1:latest|unbound-1.5.5:latest|unbound-1.6.7:latest|unbound-1.5.9:latest|unbound-1.5.1:latest|unbound-1.5.5rc1:latest|unbound-1.6.1rc3:latest|unbound-1.5.2:latest
# |   |--- test_norec >  0.50
# |   |   |--- test_zero_ttl <= 0.50
# |   |   |   |--- test_31_172 <= 0.50
# |   |   |   |   |--- class: pdns-recursor-4.0.0:latest|pdns-recursor-4.0.2:latest|pdns-recursor-4.0.4:latest|pdns-recursor-4.0.3:latest|pdns-recursor-4.0.0-rc1:latest|pdns-recursor-4.0.1:latest
# |   |   |   |--- test_31_172 >  0.50
# |   |   |   |   |--- class: pdns-recursor-4.1.14:latest|pdns-recursor-4.3.7:latest|pdns-recursor-4.4.0-rc2:latest|pdns-recursor-4.1.18:latest|pdns-recursor-4.1.4:latest|pdns-recursor-4.4.0-alpha1:latest|pdns-recursor-4.0.6:latest|pdns-recursor-4.4.3:latest|pdns-recursor-4.1.0-alpha1:latest|pdns-recursor-4.0.0-beta1:latest|pdns-recursor-4.1.11:latest|pdns-recursor-4.1.5:latest|pdns-recursor-4.1.6:latest|pdns-recursor-4.0.5-rc2:latest|pdns-recursor-4.1.7:latest|pdns-recursor-4.2.0-alpha1:latest|pdns-recursor-4.2.1:latest|pdns-recursor-4.2.2:latest|pdns-recursor-4.2.0-rc1:latest|pdns-recursor-4.3.0-beta2:latest|pdns-recursor-4.3.6:latest|pdns-recursor-4.3.0-alpha3:latest|pdns-recursor-4.1.0-rc1:latest|pdns-recursor-4.3.0:latest|pdns-recursor-4.0.5-rc1:latest|pdns-recursor-4.1.3:latest|pdns-recursor-4.4.0:latest|pdns-recursor-4.1.13:latest|pdns-recursor-4.3.1:latest|pdns-recursor-4.2.5:latest|pdns-recursor-4.4.6:latest|pdns-recursor-4.4.7:latest|pdns-recursor-4.2.0-beta1:latest|pdns-recursor-4.0.0-alpha2:latest|pdns-recursor-4.1.12:latest|pdns-recursor-4.2.4:latest|pdns-recursor-4.1.16:latest|pdns-recursor-4.2.0-rc2:latest|pdns-recursor-4.0.5:latest|pdns-recursor-4.3.4:latest|pdns-recursor-4.4.1:latest|pdns-recursor-4.3.0-rc1:latest|pdns-recursor-4.0.9:latest|pdns-recursor-4.1.0-rc2:latest|pdns-recursor-4.0.8:latest|pdns-recursor-4.1.8:latest|pdns-recursor-4.1.17:latest|pdns-recursor-4.1.10:latest|pdns-recursor-4.4.2:latest|pdns-recursor-4.4.0-alpha2:latest|pdns-recursor-4.4.0-beta1:latest|pdns-recursor-4.0.0-alpha1:latest|pdns-recursor-4.2.3:latest|pdns-recursor-4.1.0:latest|pdns-recursor-4.3.0-beta1:latest|pdns-recursor-4.1.15:latest|pdns-recursor-4.4.8:latest|pdns-recursor-4.3.0-rc2:latest|pdns-recursor-4.4.0-rc1:latest|pdns-recursor-4.3.2:latest|pdns-recursor-4.1.1:latest|pdns-recursor-4.1.2:latest|pdns-recursor-4.3.3:latest|pdns-recursor-4.4.4:latest|pdns-recursor-4.3.5:latest|pdns-recursor-4.0.7:latest|pdns-recursor-4.4.5:latest|pdns-recursor-4.3.0-alpha1:latest|pdns-recursor-4.2.0:latest
# |   |   |--- test_zero_ttl >  0.50
# |   |   |   |--- class: pdns-recursor-4.8.0-beta1:latest|pdns-recursor-4.7.0-beta1:latest|pdns-recursor-4.6.3:latest|pdns-recursor-4.7.0-alpha1:latest|pdns-recursor-4.9.1:latest|pdns-recursor-4.5.0-beta2:latest|pdns-recursor-4.5.0-alpha1:latest|pdns-recursor-4.5.5:latest|pdns-recursor-4.8.2:latest|pdns-recursor-4.7.6:latest|pdns-recursor-4.7.0-rc1:latest|pdns-recursor-4.8.0:latest|pdns-recursor-4.8.0-alpha1:latest|pdns-recursor-4.6.5:latest|pdns-recursor-4.5.10:latest|pdns-recursor-4.7.1:latest|pdns-recursor-4.7.0:latest|pdns-recursor-4.9.0-beta1:latest|pdns-recursor-4.8.4:latest|pdns-recursor-4.5.8:latest|pdns-recursor-4.5.0-beta1:latest|pdns-recursor-4.8.1:latest|pdns-recursor-4.5.0-rc1:latest|pdns-recursor-4.8.3:latest|pdns-recursor-4.9.0-alpha1:latest|pdns-recursor-4.6.6:latest|pdns-recursor-4.5.2:latest|pdns-recursor-4.6.2:latest|pdns-recursor-4.7.2:latest|pdns-recursor-4.6.4:latest|pdns-recursor-4.7.4:latest|pdns-recursor-4.5.0-alpha3:latest|pdns-recursor-4.5.9:latest|pdns-recursor-4.7.5:latest|pdns-recursor-4.9.0:latest|pdns-recursor-4.7.3:latest|pdns-recursor-4.8.5:latest|pdns-recursor-4.9.0-rc1:latest|pdns-recursor-4.8.0-rc1:latest|pdns-recursor-4.5.7:latest|pdns-recursor-4.5.1:latest|pdns-recursor-4.5.6:latest|pdns-recursor-4.5.11:latest|pdns-recursor-4.5.4:latest|pdns-recursor-4.5.12:latest|pdns-recursor-4.8.0-beta2:latest
# |--- test_home_arpa >  0.50
# |   |--- test_tc <= 0.50
# |   |   |--- test_chaos_rd <= 0.50
# |   |   |   |--- class: bind9-9.11.33:latest|bind9-9.10.8rc1:latest|bind9-9.11.5-p4:latest|bind9-9.11.28:latest|bind9-9.11.9:latest|bind9-9.11.16:latest|bind9-9.11.35:latest|bind9-9.11.6rc1:latest|bind9-9.11.12:latest|bind9-9.11.4-p1:latest|bind9-9.11.27:latest|bind9-9.10.8rc2:latest|bind9-9.11.19:latest|bind9-9.11.4-p2:latest|bind9-9.11.4rc1:latest|bind9-9.11.4rc2:latest|bind9-9.11.5:latest|bind9-9.11.29:latest|bind9-9.11.5rc1:latest|bind9-9.11.13:latest|bind9-9.11.36:latest|bind9-9.11.17:latest|bind9-9.11.25:latest|bind9-9.11.21:latest|bind9-9.11.32:latest|bind9-9.11.26:latest|bind9-9.11.18:latest|bind9-9.11.24:latest|bind9-9.11.7:latest|bind9-9.11.5-p1:latest|bind9-9.11.14:latest|bind9-9.11.34:latest|bind9-9.10.8:latest|bind9-9.11.8:latest|bind9-9.11.23:latest|bind9-9.11.10:latest|bind9-9.11.15:latest|bind9-9.10.8-p1:latest|bind9-9.11.20:latest|bind9-9.11.6-p1:latest|bind9-9.11.37:latest|bind9-9.11.11:latest|bind9-9.11.31:latest|bind9-9.11.4:latest|bind9-9.11.6:latest|bind9-9.11.22:latest
# |   |   |--- test_chaos_rd >  0.50
# |   |   |   |--- class: unbound-1.16.0:latest|unbound-1.17.1rc1:latest|unbound-1.17.0:latest|unbound-1.15.0:latest|unbound-1.14.0:latest|unbound-1.16.3:latest|unbound-1.17.1rc2:latest|unbound-1.16.0rc1:latest|unbound-1.16.1rc1:latest|unbound-1.15.0rc1:latest|unbound-1.16.2:latest|unbound-1.17.0rc1:latest|unbound-1.17.1:latest|unbound-1.16.1:latest|unbound-1.14.0rc1:latest
# |   |--- test_tc >  0.50
# |   |   |--- class: bind9-9.19.6:latest|bind9-9.16.19:latest|bind9-9.16.34:latest|bind9-9.19.12:latest|bind9-9.13.7:latest|bind9-9.18.4:latest|bind9-9.16.32:latest|bind9-9.14.7:latest|bind9-9.17.1:latest|bind9-9.16.29:latest|bind9-9.17.4:latest|bind9-9.18.16:latest|bind9-9.16.40:latest|bind9-9.18.13:latest|bind9-9.15.0:latest|bind9-9.19.9:latest|bind9-9.18.8:latest|bind9-9.17.16:latest|bind9-9.14.4:latest|bind9-9.18.2:latest|bind9-9.16.36:latest|bind9-9.15.5:latest|bind9-9.16.25:latest|bind9-9.15.4:latest|bind9-9.16.0:latest|bind9-9.16.39:latest|bind9-9.12.2-p2:latest|bind9-9.16.26:latest|bind9-9.16.22:latest|bind9-9.19.5:latest|bind9-9.18.15:latest|bind9-9.16.20:latest|bind9-9.18.1:latest|bind9-9.13.5-w1:latest|bind9-9.16.7:latest|bind9-9.19.3:latest|bind9-9.17.11:latest|bind9-9.14.0rc3:latest|bind9-9.16.6:latest|bind9-9.16.24:latest|bind9-9.16.9:latest|bind9-9.17.5:latest|bind9-9.12.3-p4:latest|bind9-9.12.2:latest|bind9-9.16.28:latest|bind9-9.17.8:latest|bind9-9.18.12:latest|bind9-9.17.18:latest|bind9-9.17.14:latest|bind9-9.14.6:latest|bind9-9.18.17:latest|bind9-9.19.1:latest|bind9-9.14.10:latest|bind9-9.17.3:latest|bind9-9.14.9:latest|bind9-9.17.13:latest|bind9-9.18.9:latest|bind9-9.12.4:latest|bind9-9.16.1:latest|bind9-9.12.2-p1:latest|bind9-9.16.30:latest|bind9-9.16.10:latest|bind9-9.15.6:latest|bind9-9.17.2:latest|bind9-9.19.14:latest|bind9-9.16.38:latest|bind9-9.18.14:latest|bind9-9.12.3-p1:latest|bind9-9.16.42:latest|bind9-9.16.23:latest|bind9-9.19.13:latest|bind9-9.16.41:latest|bind9-9.18.0:latest|bind9-9.16.8:latest|bind9-9.17.22:latest|bind9-9.14.11:latest|bind9-9.19.4:latest|bind9-9.16.13:latest|bind9-9.16.18:latest|bind9-9.13.3:latest|bind9-9.14.5:latest|bind9-9.13.4:latest|bind9-9.18.10:latest|bind9-9.14.0:latest|bind9-9.14.3:latest|bind9-9.12.2rc2:latest|bind9-9.16.5:latest|bind9-9.14.8:latest|bind9-9.16.16:latest|bind9-9.19.0:latest|bind9-9.13.2:latest|bind9-9.12.4-p2:latest|bind9-9.14.2:latest|bind9-9.18.18:latest|bind9-9.14.12:latest|bind9-9.17.15:latest|bind9-9.16.12:latest|bind9-9.16.37:latest|bind9-9.19.11:latest|bind9-9.13.1:latest|bind9-9.17.9:latest|bind9-9.15.2:latest|bind9-9.16.17:latest|bind9-9.16.31:latest|bind9-9.17.17:latest|bind9-9.17.7:latest|bind9-9.17.19:latest|bind9-9.16.35:latest|bind9-9.18.5:latest|bind9-9.16.15:latest|bind9-9.16.27:latest|bind9-9.15.7:latest|bind9-9.15.3:latest|bind9-9.16.4:latest|bind9-9.16.33:latest|bind9-9.16.3:latest|bind9-9.12.3rc1:latest|bind9-9.18.6:latest|bind9-9.17.10:latest|bind9-9.12.3:latest|bind9-9.19.16:latest|bind9-9.18.3:latest|bind9-9.18.11:latest|bind9-9.14.0rc2:latest|bind9-9.17.6:latest|bind9-9.16.21:latest|bind9-9.17.12:latest|bind9-9.14.0rc1:latest|bind9-9.14.1:latest|bind9-9.19.10:latest|bind9-9.15.1:latest|bind9-9.17.0:latest|bind9-9.13.5:latest|bind9-9.16.11:latest|bind9-9.19.8:latest|bind9-9.12.2rc1:latest|bind9-9.17.21:latest|bind9-9.12.4-p1:latest|bind9-9.19.7:latest|bind9-9.19.15:latest|bind9-9.15.8:latest|bind9-9.12.4rc1:latest|bind9-9.13.6:latest|bind9-9.17.20:latest|bind9-9.16.43:latest|bind9-9.18.7:latest|bind9-9.16.2:latest|bind9-9.19.2:latest

# %%
# Analyze the feature importance, i.e. which ones were used to build the tree, and which ones not
feature_importances = pd.DataFrame(data=clf.feature_importances_,columns=["importance"],index=X_train.columns)

print(f"The total number of features: {feature_importances.shape[0]}")
print(f"  Important features: {feature_importances[feature_importances['importance'] != 0].shape[0]}")
print(f"  Not important features: {feature_importances[feature_importances['importance'] == 0].shape[0]}")

# Now we aggregate by the testcase names
testcases_all = set(i[:i.index("(")][:-1] for i in feature_importances.index.to_list())
testcases_important = set(i[:i.index("(")][:-1] for i in feature_importances[feature_importances['importance'] != 0].index.to_list())
testcases_not_important_all = set(i[:i.index("(")][:-1] for i in feature_importances[feature_importances['importance'] == 0].index.to_list())
testcases_not_important_unique = testcases_all - testcases_important

print("---")
print(f"The total number of testcases: {len(testcases_all)}")
print(f"  Important testcases: {len(testcases_important)} ({', '.join(testcases_important)})")
print(f"  Not important testcases: {len(testcases_not_important_unique)} ({', '.join(testcases_not_important_unique)})")

# Also check how many unique versions we got out of all:
# versions_all = df_one_hot
labels_all = set(df_one_hot["label"].to_list())
labels_individual = [i for i in labels_all if "|" not in i]
versions_all = set(j for i in labels_all for j in i.split("|"))
print("---")
print(f"All versions: {len(versions_all)}")
print(f"  Fingerprints: {len(labels_all)}")
print(f"    Individual versions: {len(labels_individual)}")
# Out:
# The total number of features: 56
#   Important features: 37
#   Not important features: 19
# ---
# The total number of testcases: 10
#   Important testcases: 10 (test_edns0, test_zero_ttl, test_tc, test_chaos_rd, test_iquery, test_is_response, test_norec, test_home_arpa, test_31_172, test_baseline)
#   Not important testcases: 0 ()
# ---
# All versions: 674
#   Fingerprints: 72
#     Individual versions: 9
